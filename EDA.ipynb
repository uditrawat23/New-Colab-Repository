# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_excel('transaction.xlsx')
df.head()
# Out:
#                                      id  ProdID CustomerID         label  \
# 0  4eb7eb9d-3ad9-82ad-ed4e-26c0536bb12e   49286     Cu5380  purchased by
# 1  c2b7eb9d-3ad9-d402-83d8-4f664e132d09   49286     Cu5381  purchased by
# 2  0ab7ec08-2377-863c-98f1-0aec8069c4d2   49340     Cu4476  purchased by
# 3  0eb7ec08-2377-cbc8-6477-4fa8b5011fef   49340     Cu4477  purchased by
# 4  6eb7ec08-2377-ad6a-8403-b7769afb7172   49340     Cu4478  purchased by
#
#    Account               InvDate  UnitsPerCase  NetCost  Margin% custtype  \
# 0   104605   2018-11-28 00:00:00          1.00   122.72   0.4497      C17
# 1   104605   2018-11-28 00:00:00          1.00   122.72   0.4497      C17
# 2   240135   2018-11-26 00:00:00          0.01  1016.01   0.1400      C13
# 3   240135   2018-11-26 00:00:00          0.01  1016.01   0.1400      C13
# 4   240135   2018-11-26 00:00:00          0.01  1016.01   0.1400      C13
#
#    ...   Qty  CommodityCode            ProductCategory vendno RebateAmt  \
# ...

# %%
# shape

df.shape
# Out:
# (29576, 25)

# %%
# columns details

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29576 entries, 0 to 29575
# Data columns (total 25 columns):
# id                    29576 non-null object
# ProdID                29576 non-null int64
# CustomerID            29576 non-null object
# label                 29576 non-null object
# Account               29576 non-null int64
# InvDate               29576 non-null object
# UnitsPerCase          29576 non-null float64
# NetCost               29576 non-null float64
# Margin%               28668 non-null float64
# custtype              29576 non-null object
# CostAmt               29576 non-null float64
# Line                  29576 non-null int64
#  SalesAmt             29576 non-null float64
#  unit                 29576 non-null object
# CusttypeDescrip       29089 non-null object
#  Qty                  29576 non-null int64
# CommodityCode         29576 non-null int64
# ProductCategory       29576 non-null object
# vendno                29576 non-null object
# ...

# %%
# describe

df.describe()
# Out:
#               ProdID       Account  UnitsPerCase       NetCost       Margin%  \
# count   29576.000000  2.957600e+04  29576.000000  29576.000000  28668.000000
# mean    43257.785907  2.284486e+05      0.225500     92.630160      0.255029
# std     21420.268805  1.151209e+05      0.408546    506.345296      0.126245
# min        75.000000  3.890000e+02      0.010000  -4003.560000     -2.907200
# 25%     27066.000000  1.703250e+05      0.010000      2.953600      0.150117
# 50%     45522.000000  2.800490e+05      0.010000     13.880000      0.250000
# 75%     56521.000000  2.800500e+05      0.010000     54.400000      0.304706
# max    103902.000000  2.000007e+06      1.000000  32771.200000      0.999998
#
#             CostAmt          Line      SalesAmt           Qty  CommodityCode  \
# count  29576.000000  29576.000000  29576.000000  29576.000000   29576.000000
# mean      96.020880      6.692250    113.813673     60.231032    2394.808291
# ...

# %%
# Checking null values

df.isnull().sum()
# Out:
# id                      0
# ProdID                  0
# CustomerID              0
# label                   0
# Account                 0
# InvDate                 0
# UnitsPerCase            0
# NetCost                 0
# Margin%               908
# custtype                0
# CostAmt                 0
# Line                    0
#  SalesAmt               0
#  unit                   0
# CusttypeDescrip       487
#  Qty                    0
# CommodityCode           0
# ProductCategory         0
# vendno                  0
# RebateAmt               0
# Profit                  0
# ProductDescription      0
# OrderSuffix             0
# VendorNo/Name           0
# OrderNo                 0
# dtype: int64

# %%
# There are NaN values as string
# Remove NAN rows

df = df.dropna()
df.shape
# Out:
# (28181, 25)

# %%
int_columns = df.select_dtypes(include=['int64','float64'])
int_columns.head()
# Out:
#    ProdID  Account  UnitsPerCase  NetCost  Margin%  CostAmt  Line   SalesAmt  \
# 0   49286   104605          1.00   122.72   0.4497   122.72    11     223.00
# 1   49286   104605          1.00   122.72   0.4497   122.72    11     223.00
# 2   49340   240135          0.01  1016.01   0.1400  1016.01     1    1181.41
# 3   49340   240135          0.01  1016.01   0.1400  1016.01     1    1181.41
# 4   49340   240135          0.01  1016.01   0.1400  1016.01     1    1181.41
#
#     Qty  CommodityCode  RebateAmt  Profit  OrderSuffix  OrderNo
# 0    25           2511        0.0   100.0            0  3240215
# 1    25           2511        0.0   100.0            0  3240215
# 2    13           2210        0.0   165.0            0  3233756
# 3    13           2210        0.0   165.0            0  3233756
# 4    13           2210        0.0   165.0            0  3233756

# %%
# paiwise scatter plot

plt.figure(figsize=(100, 100))
sns.pairplot(int_columns)
plt.show()

# %%
all_col = list(df.select_dtypes(['object']))
all_col
# Out:
# ['id',
#  'CustomerID',
#  'label',
#  'InvDate',
#  'custtype',
#  ' unit',
#  'CusttypeDescrip',
#  'ProductCategory',
#  'vendno',
#  'ProductDescription',
#  'VendorNo/Name']

# %%
Removing =['id', 'CustomerID','custtype','CusttypeDescrip', 'ProductCategory', 'vendno',  'ProductDescription', 'VendorNo/Name']

# %%
all_col1= ['label', 'InvDate', ' unit']
for i in all_col1:
    print('value_count: ',i)
    print(df[i].value_counts(normalize=True))
    print('*'*20)
# Out:
# value_count:  label
# purchased by    1.0
# Name: label, dtype: float64
# ********************
# value_count:  InvDate
#  2018-11-28 00:00:00    0.367695
#  2018-11-27 00:00:00    0.258649
#  2018-11-26 00:00:00    0.211242
#  2018-11-29 00:00:00    0.162414
# Name: InvDate, dtype: float64
# ********************
# value_count:   unit
# EA      0.755757
# FT      0.231965
# each    0.006352
# E       0.002377
# EACH    0.001206
# PR      0.001206
# PK      0.000639
# ea      0.000426
# PC      0.000071
# Name:  unit, dtype: float64
# ********************

# %%
pd.value_counts(df['label']).plot(kind="bar")

# %%
pd.value_counts(df['InvDate']).plot(kind="bar")

# %%
pd.value_counts(df[' unit']).plot(kind="bar")

# %%
fig = plt.figure(figsize=(14,12))

#  subplot #1
fig.add_subplot(231)
plt.title('subplot(231) - title', fontsize=14)
sns.countplot(data=df, x='id')

#  subplot #2
fig.add_subplot(2,3,2)
plt.title('subplot(2,3,2)', fontsize=14)
sns.countplot(data=df,x='id')

#  subplot #3
fig.add_subplot(233)
plt.title('subplot(233)', fontsize=14)
sns.countplot(data=df, x=df['id'])

#  subplot #4
fig.add_subplot(2,3,4)
plt.title('subplot(2,3,4)', fontsize=14)
sns.countplot(data=df, x=df['id'])

#  subplot #5
fig.add_subplot(235)
plt.title('subplot(235)', fontsize=14)
sns.countplot(data=df, x=['id'])

plt.show()

# %%
from sklearn.preprocessing import LabelEncoder

item_encoder = LabelEncoder()
category_encoder = LabelEncoder()
df['item_id'] = item_encoder.fit_transform(df.item_id )
df['category']= category_encoder.fit_transform(df.category.apply(str))
df.head()

# %%
df.isnull().sum()
# Out:
# id                      0
# ProdID                  0
# CustomerID              0
# label                   0
# Account                 0
# InvDate                 0
# UnitsPerCase            0
# NetCost                 0
# Margin%               908
# custtype                0
# CostAmt                 0
# Line                    0
#  SalesAmt               0
#  unit                   0
# CusttypeDescrip       487
#  Qty                    0
# CommodityCode           0
# ProductCategory         0
# vendno                  0
# RebateAmt               0
# Profit                  0
# ProductDescription      0
# OrderSuffix             0
# VendorNo/Name           0
# OrderNo                 0
# dtype: int64

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
data['Survived'].value_counts().plot.pie(explode=[0,0.1],autopct='%1.1f%%',ax=ax[0],shadow=True)
ax[0].set_title('Survived')
ax[0].set_ylabel('')
sns.countplot('Survived',data=data,ax=ax[1])
ax[1].set_title('Survived')
plt.show()
